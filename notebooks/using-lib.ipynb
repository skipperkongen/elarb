# %%
import datetime
from elarb import datasets, util

# %%
today = datetime.date.today() - datetime.timedelta(days=2)
intwodays = today + datetime.timedelta(days=20)
print(today.isoformat(), intwodays.isoformat())
# Out:
# 2022-10-07 2022-10-27

# %%
df = datasets.download_nordpool('2022-10-08', '2022-10-11')  # intwodays.isoformat()

# %%
util.spot_heatmap(df)

# %%
util.pivot_to_hm(df)
# Out:
#     2022_10_07  2022_10_08  2022_10_09
# 0      0.12638     0.33231     0.72518
# 1      0.03615     0.33514     0.72243
# 2      0.01004     0.34748     0.74972
# 3      0.00409     0.34882     0.75315
# 4      0.00573     0.34860     0.75367
# 5      0.00603     0.35120     0.74972
# 6      0.08115     0.36608     0.89982
# 7      0.59530     0.46961     1.45542
# 8      0.59545     0.52219     1.46300
# 9      0.36158     0.52242     1.12198
# 10     0.29687     0.39040     0.76207
# 11     0.15271     0.34005     0.65222
# 12     0.10458     0.27199     0.44604
# 13     0.10220     0.26032     0.37189
# 14     0.14535     0.22268     0.40722
# 15     0.13389     0.22246     0.38260
# 16     0.17205     0.31171     0.98461
# 17     0.25224     0.33774     1.36170
# 18     0.38658     0.64767     1.47892
# 19     0.37155     0.09728     1.92444
# 20     0.28980     0.31186     1.07884
# 21     0.37148     0.31223     0.70510
# 22     0.38077     0.31201     0.68940
# ...
